# %%
import pandas as pd

# %%
cities = pd.read_csv("cities.csv")
cities
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
city_index = cities.index
city_index
# Out:
# RangeIndex(start=0, stop=493, step=1)

# %%
city_columns = cities.columns
city_columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
cities.dtypes
# Out:
# name_of_city                       object
# state_code                          int64
# state_name                         object
# dist_code                           int64
# population_total                    int64
# population_male                     int64
# population_female                   int64
# 0-6_population_total                int64
# 0-6_population_male                 int64
# 0-6_population_female               int64
# literates_total                     int64
# literates_male                      int64
# literates_female                    int64
# sex_ratio                           int64
# child_sex_ratio                     int64
# effective_literacy_rate_total     float64
# effective_literacy_rate_male      float64
# effective_literacy_rate_female    float64
# location                           object
# total_graduates                     int64
# male_graduates                      int64
# female_graduates                    int64
# dtype: object

# %%
cities.values
# Out:
# array([['Abohar ', 3, 'PUNJAB', ..., 16287, 8612, 7675],
#        ['Achalpur ', 27, 'MAHARASHTRA', ..., 8863, 5269, 3594],
#        ['Adilabad ', 28, 'ANDHRA PRADESH', ..., 10565, 6797, 3768],
#        ...,
#        ['Wardha ', 27, 'MAHARASHTRA', ..., 19363, 10645, 8718],
#        ['Yamunanagar ', 6, 'HARYANA', ..., 29803, 14349, 15454],
#        ['Yavatmal ', 27, 'MAHARASHTRA', ..., 13511, 7397, 6114]],
#       dtype=object)

# %%
cities.shape
# Out:
# (493, 22)

# %%
cities.head(8)
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
# 5    Agartala           16         TRIPURA          1            399688
# 6        Agra            9   UTTAR PRADESH         15           1574542
# 7   Ahmadabad           24         GUJARAT          7           5570585
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# ...

# %%
cities.tail(10)
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 483       Vellore           33      TAMIL NADU          4            185895
# 484       Veraval           24         GUJARAT         12            153696
# 485       Vidisha           23  MADHYA PRADESH         26            155959
# 486    Vijayawada           28  ANDHRA PRADESH         16           1048240
# 487  Visakhapatnam          28  ANDHRA PRADESH         13           1730320
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
#      population_male  population_female  0-6_population_total  \
# 483            91464              94431                 18363
# ...

# %%
cities.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# ...

# %%
cities['state_name']
# Out:
# 0              PUNJAB
# 1         MAHARASHTRA
# 2      ANDHRA PRADESH
# 3           JHARKHAND
# 4      ANDHRA PRADESH
#             ...
# 488    ANDHRA PRADESH
# 489    ANDHRA PRADESH
# 490       MAHARASHTRA
# 491           HARYANA
# 492       MAHARASHTRA
# Name: state_name, Length: 493, dtype: object

# %%
cities['state_name'].unique()
# Out:
# array(['PUNJAB', 'MAHARASHTRA', 'ANDHRA PRADESH', 'JHARKHAND', 'TRIPURA',
#        'UTTAR PRADESH', 'GUJARAT', 'MIZORAM', 'RAJASTHAN', 'TAMIL NADU',
#        'KERALA', 'HARYANA', 'CHHATTISGARH', 'JAMMU & KASHMIR', 'BIHAR',
#        'WEST BENGAL', 'KARNATAKA', 'ORISSA', 'MADHYA PRADESH',
#        'NCT OF DELHI', 'CHANDIGARH', 'UTTARAKHAND', 'ASSAM', 'NAGALAND',
#        'MANIPUR ', 'PUDUCHERRY', 'ANDAMAN & NICOBAR ISLANDS', 'MEGHALAYA',
#        'HIMACHAL PRADESH'], dtype=object)

# %%
# code to find the name of state starting with "AN" and name of city starting with "Vi" using LAMBDA function.

# %%
cities[(cities['state_name'].apply(lambda x:x[:2])=='AN')&(cities['name_of_city'].apply(lambda x:x[:2])=='Vi')]
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 486    Vijayawada           28  ANDHRA PRADESH         16           1048240
# 487  Visakhapatnam          28  ANDHRA PRADESH         13           1730320
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
#
#      population_male  population_female  0-6_population_total  \
# 486           524918             523322                 92848
# 487           875199             855121                158924
# 488           111596             115937                 20487
#
#      0-6_population_male  0-6_population_female  ...  literates_female  \
# 486                47582                  45266  ...            377361
# 487                81119                  77805  ...            599937
# 488                10495                   9992  ...             80306
#
#      sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# ...

# %%
cities.loc[1:25,'state_name']
# Out:
# 1        MAHARASHTRA
# 2     ANDHRA PRADESH
# 3          JHARKHAND
# 4     ANDHRA PRADESH
# 5            TRIPURA
# 6      UTTAR PRADESH
# 7            GUJARAT
# 8        MAHARASHTRA
# 9            MIZORAM
# 10         RAJASTHAN
# 11     UTTAR PRADESH
# 12       MAHARASHTRA
# 13        TAMIL NADU
# 14            KERALA
# 15     UTTAR PRADESH
# 16     UTTAR PRADESH
# 17         RAJASTHAN
# 18           HARYANA
# 19           HARYANA
# 20       MAHARASHTRA
# 21        TAMIL NADU
# 22      CHHATTISGARH
# 23        TAMIL NADU
# 24       MAHARASHTRA
# 25           GUJARAT
# Name: state_name, dtype: object

# %%
cities.loc[1:25,'state_name'].unique()
# Out:
# array(['MAHARASHTRA', 'ANDHRA PRADESH', 'JHARKHAND', 'TRIPURA',
#        'UTTAR PRADESH', 'GUJARAT', 'MIZORAM', 'RAJASTHAN', 'TAMIL NADU',
#        'KERALA', 'HARYANA', 'CHHATTISGARH'], dtype=object)

# %%
cities.iloc[1:26]
# Out:
#      name_of_city  state_code      state_name  dist_code  population_total  \
# 1       Achalpur           27     MAHARASHTRA          7            112293
# 2       Adilabad           28  ANDHRA PRADESH          1            117388
# 3      Adityapur           20       JHARKHAND         24            173988
# 4          Adoni           28  ANDHRA PRADESH         21            166537
# 5       Agartala           16         TRIPURA          1            399688
# 6           Agra            9   UTTAR PRADESH         15           1574542
# 7      Ahmadabad           24         GUJARAT          7           5570585
# 8     Ahmadnagar           27     MAHARASHTRA         26            350905
# 9         Aizawl           15         MIZORAM          3            291822
# 10         Ajmer            8       RAJASTHAN         21            542580
# 11      Akbarpur            9   UTTAR PRADESH         47            111594
# ...

# %%
cities[cities['state_name']=='WEST BENGAL']
# Out:
#                name_of_city  state_code   state_name  dist_code  \
# 32                 Asansol           19  WEST BENGAL          9
# 33   Ashoknagar Kalyangarh           19  WEST BENGAL         11
# 42              Baharampur           19  WEST BENGAL          7
# 44              Baidyabati           19  WEST BENGAL         12
# 47                   Bally           19  WEST BENGAL         15
# ..                      ...         ...          ...        ...
# 436               Siliguri           19  WEST BENGAL         99
# 443          South Dum Dum           19  WEST BENGAL         11
# 468               Titagarh           19  WEST BENGAL         11
# 476               Uluberia           19  WEST BENGAL         15
# 478      Uttarpara Kotrung           19  WEST BENGAL         12
#
#      population_total  population_male  population_female  \
# 32             564491           293748             270743
# 33             123906            62554              61352
# ...

# %%
cities[cities['population_total']>2000000]
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 7            Ahmadabad           24         GUJARAT          7
# 72            Bengaluru          29       KARNATAKA         18
# 119            Chennai           33      TAMIL NADU          2
# 141              Delhi            7    NCT OF DELHI         99
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 225             Jaipur            8       RAJASTHAN         12
# 251             Kanpur            9   UTTAR PRADESH         33
# 274            Kolkata           19     WEST BENGAL         16
# 288            Lucknow            9   UTTAR PRADESH         26
# 334             Nagpur           27     MAHARASHTRA          9
# 380               Pune           27     MAHARASHTRA         25
# 449              Surat           24         GUJARAT         25
#
#      population_total  population_male  population_female  \
# ...

# %%
test=cities.loc[cities['population_total']>2000000,['population_total','state_name']]

# %%
test
# Out:
#      population_total      state_name
# 7             5570585         GUJARAT
# 72            8425970       KARNATAKA
# 119           4681087      TAMIL NADU
# 141          11007835    NCT OF DELHI
# 184           6809970  ANDHRA PRADESH
# 185          12478447     MAHARASHTRA
# 225           3073350       RAJASTHAN
# 251           2767031   UTTAR PRADESH
# 274           4486679     WEST BENGAL
# 288           2815601   UTTAR PRADESH
# 334           2405421     MAHARASHTRA
# 380           3115431     MAHARASHTRA
# 449           4462002         GUJARAT

# %%
test[test['state_name']=='MAHARASHTRA']
# Out:
#      population_total   state_name
# 185          12478447  MAHARASHTRA
# 334           2405421  MAHARASHTRA
# 380           3115431  MAHARASHTRA
